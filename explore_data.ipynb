# %%
import os
import numpy as np
import pandas as pd
sepsis_data_path = '/home/guido/Code/charite/baselines/data/processed_sepsis/'
raw_sepsis = pd.read_parquet(os.path.join(sepsis_data_path, 'raw_sepsis_features.parquet'))
sepsis_cohort = pd.read_parquet(os.path.join(sepsis_data_path, 'sepsis_cohort.parquet'))

# %%
raw_sepsis.head()
### Print unique features
print("There are ", len(raw_sepsis["feature_name"].unique()), "features: ")
print(raw_sepsis["feature_name"].unique())
# Out:
# ['heart_rate' 'sbp' 'dbp' 'respiratory_rate' 'spo2' 'gcs_comp' 'mbp'
#  'temperature' 'platelets' 'wbc' 'creatinine' 'glucose' 'lactate'
#  'bilirubin' 'paco2' 'ph' 'pao2' 'norepi_equiv' 'fluid_volume'
#  'urine_output']
# There are  20 features
